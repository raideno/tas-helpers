# %%
import matplotlib.pyplot as plt

from tas_helpers.visualization import SegmentationVisualizer
from tas_helpers.utils import generate_random_segmentation

# %%
FPS = 20
DURATION_IN_SECONDS = 10
DURATION_IN_FRAMES = DURATION_IN_SECONDS * FPS

# %%
# NOTE: create sample data
labels = ["cooking", "eating", "cleaning"]
segmentation = generate_random_segmentation(length=DURATION_IN_FRAMES, labels=labels)

# NOTE: visualize it
visualizer = SegmentationVisualizer(labels_values=labels)
visualizer.plot_segmentation(segmentation, fps=FPS, header="My Video Segmentation")
# Out:
# <Axes: title={'center': 'My Video Segmentation'}>
